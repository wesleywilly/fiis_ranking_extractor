# %%
import pandas as pd

#Listando arquivos presentes no diretório
from os import listdir
from os.path import isfile, join
path = 'tables/'

# %%
#Lendo o arquivo
df = pd.read_json(path+'fii_info.json')

# %%
df.head()
# Out:
#          id           link  tipo_desenvolvimento  tipo_fof  tipo_titulos  \
# 0    BCRI11  /funds/bcri11                   NaN       NaN          True
# 1    BNFS11  /funds/bnfs11                   NaN       NaN         False
# 10   CBOP11  /funds/cbop11                   NaN       NaN         False
# 100  MGFF11  /funds/mgff11                   NaN       NaN          True
# 101  IRDM11  /funds/irdm11                   NaN       NaN          True
#
#      tipo_hospital  tipo_residencial  tipo_lajes_corporativas  tipo_shopping  \
# 0            False             False                    False          False
# 1            False             False                    False          False
# 10           False             False                     True          False
# 100          False             False                    False          False
# 101          False             False                    False          False
#
# ...

# %%
df.dtypes

# %% [markdown]
# # Sem Tipo definido

# %%
df[~df.tipo_hospital & ~df.tipo_residencial & ~df.tipo_lajes_corporativas & ~df.tipo_shopping & ~df.tipo_galpoes_logisticos]
# Out:
#           id            link  tipo_desenvolvimento  tipo_fof  tipo_titulos  \
# 0     BCRI11   /funds/bcri11                   NaN       NaN          True
# 1     BNFS11   /funds/bnfs11                   NaN       NaN         False
# 100   MGFF11   /funds/mgff11                   NaN       NaN          True
# 101   IRDM11   /funds/irdm11                   NaN       NaN          True
# 102   HFOF11   /funds/hfof11                   NaN       NaN          True
# 105   OUCY11   /funds/oucy11                   NaN       NaN          True
# 106   HBTT11   /funds/hbtt11                   NaN       NaN         False
# 107   RBRR11   /funds/rbrr11                   NaN       NaN          True
# 108   RDPD11   /funds/rdpd11                   NaN       NaN          True
# 110   HGRU11   /funds/hgru11                   NaN       NaN         False
# 111  NVIF11B  /funds/nvif11b                   NaN       NaN         False
# ...

# %% [markdown]
# # Sem Data de Constituição

# %%
df[df.data_constituicao.isna()]
# Out:
#           id            link  tipo_desenvolvimento  tipo_fof  tipo_titulos  \
# 0     BCRI11   /funds/bcri11                   NaN       NaN          True
# 1     BNFS11   /funds/bnfs11                   NaN       NaN         False
# 10    CBOP11   /funds/cbop11                   NaN       NaN         False
# 100   MGFF11   /funds/mgff11                   NaN       NaN          True
# 101   IRDM11   /funds/irdm11                   NaN       NaN          True
# 102   HFOF11   /funds/hfof11                   NaN       NaN          True
# 103   WPLZ11   /funds/wplz11                   NaN       NaN         False
# 104   XPLG11   /funds/xplg11                   NaN       NaN         False
# 105   OUCY11   /funds/oucy11                   NaN       NaN          True
# 106   HBTT11   /funds/hbtt11                   NaN       NaN         False
# 107   RBRR11   /funds/rbrr11                   NaN       NaN          True
# ...

# %% [markdown]
# # Sem Tipo de Gestão

# %%
df[df.tipo_gestao.isna()]
# Out:
#           id            link  tipo_desenvolvimento  tipo_fof  tipo_titulos  \
# 0     BCRI11   /funds/bcri11                   NaN       NaN          True
# 1     BNFS11   /funds/bnfs11                   NaN       NaN         False
# 10    CBOP11   /funds/cbop11                   NaN       NaN         False
# 100   MGFF11   /funds/mgff11                   NaN       NaN          True
# 101   IRDM11   /funds/irdm11                   NaN       NaN          True
# 102   HFOF11   /funds/hfof11                   NaN       NaN          True
# 103   WPLZ11   /funds/wplz11                   NaN       NaN         False
# 104   XPLG11   /funds/xplg11                   NaN       NaN         False
# 105   OUCY11   /funds/oucy11                   NaN       NaN          True
# 106   HBTT11   /funds/hbtt11                   NaN       NaN         False
# 107   RBRR11   /funds/rbrr11                   NaN       NaN          True
# ...

# %% [markdown]
# # Sem Público Alvo

# %%
df[df.publico_alvo.isna()]
# Out:
#           id            link  tipo_desenvolvimento  tipo_fof  tipo_titulos  \
# 0     BCRI11   /funds/bcri11                   NaN       NaN          True
# 1     BNFS11   /funds/bnfs11                   NaN       NaN         False
# 10    CBOP11   /funds/cbop11                   NaN       NaN         False
# 100   MGFF11   /funds/mgff11                   NaN       NaN          True
# 101   IRDM11   /funds/irdm11                   NaN       NaN          True
# 102   HFOF11   /funds/hfof11                   NaN       NaN          True
# 103   WPLZ11   /funds/wplz11                   NaN       NaN         False
# 104   XPLG11   /funds/xplg11                   NaN       NaN         False
# 105   OUCY11   /funds/oucy11                   NaN       NaN          True
# 106   HBTT11   /funds/hbtt11                   NaN       NaN         False
# 107   RBRR11   /funds/rbrr11                   NaN       NaN          True
# ...

# %% [markdown]
# # Sem Prazo definido

# %%
df[df.tem_prazo.isna()]
# Out:
#           id            link  tipo_desenvolvimento  tipo_fof  tipo_titulos  \
# 0     BCRI11   /funds/bcri11                   NaN       NaN          True
# 1     BNFS11   /funds/bnfs11                   NaN       NaN         False
# 10    CBOP11   /funds/cbop11                   NaN       NaN         False
# 100   MGFF11   /funds/mgff11                   NaN       NaN          True
# 101   IRDM11   /funds/irdm11                   NaN       NaN          True
# 102   HFOF11   /funds/hfof11                   NaN       NaN          True
# 103   WPLZ11   /funds/wplz11                   NaN       NaN         False
# 104   XPLG11   /funds/xplg11                   NaN       NaN         False
# 105   OUCY11   /funds/oucy11                   NaN       NaN          True
# 106   HBTT11   /funds/hbtt11                   NaN       NaN         False
# 107   RBRR11   /funds/rbrr11                   NaN       NaN          True
# ...

# %% [markdown]
# # Editor individual

# %%
#digite o ID do FII aqui
fii_id = 1

#Valores Atuais
df.iloc[fii_id]
# Out:
# id                                BNFS11
# link                       /funds/bnfs11
# tipo_desenvolvimento                 NaN
# tipo_fof                             NaN
# tipo_titulos                       False
# tipo_hospital                      False
# tipo_residencial                   False
# tipo_lajes_corporativas            False
# tipo_shopping                      False
# tipo_agencias_bancarias              NaN
# tipo_galpoes_logisticos            False
# tipo_compra_e_venda                  NaN
# tipo_cri                             NaN
# quantidade_ativos                     18
# data_constituicao                    NaN
# tipo_gestao                          NaN
# publico_alvo                         NaN
# tem_prazo                            NaN
# black_list                         False
# Name: 1, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'link', 'tipo_desenvolvimento', 'tipo_fof', 'tipo_titulos',
#        'tipo_hospital', 'tipo_residencial', 'tipo_lajes_corporativas',
#        'tipo_shopping', 'tipo_agencias_bancarias', 'tipo_galpoes_logisticos',
#        'tipo_compra_e_venda', 'tipo_cri', 'quantidade_ativos',
#        'data_constituicao', 'tipo_gestao', 'publico_alvo', 'tem_prazo',
#        'black_list'],
#       dtype='object')

# %%
#Edite os valores

#df.iloc[fii_id]['tipo_desenvolvimento'] = True
#df.iloc[fii_id]['tipo_fof'] = True
#df.iloc[fii_id]['tipo_titulos'] = True
#df.iloc[fii_id]['tipo_hospital'] = True
#df.iloc[fii_id]['tipo_residencial'] = True
#df.iloc[fii_id]['tipo_lajes_corporativas'] = True
#df.iloc[fii_id]['tipo_shopping'] = True
#df.iloc[fii_id]['tipo_agencias_bancarias'] = True
#df.iloc[fii_id]['tipo_galpoes_logisticos'] = True
#df.iloc[fii_id]['tipo_compra_e_venda'] = True
#df.iloc[fii_id]['tipo_cri'] = True
#df.iloc[fii_id]['quantidade_ativos'] = 0
#df.iloc[fii_id]['data_constituicao'] = pd.to_datetime('2019-12-31')
#df.iloc[fii_id]['tipo_gestao'] = 'ativa'
#df.iloc[fii_id]['publico_alvo'] = ''
#df.iloc[fii_id]['tem_prazo'] = True
#df.iloc[fii_id]['black_list'] = True
# Out:
# '/funds/bnfs11'

# %% [markdown]
# # Salvar alterações

# %%
df.to_json(path+'fii_info.json')
